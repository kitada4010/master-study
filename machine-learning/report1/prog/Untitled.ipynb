# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Num = 10
x = np.random.randn(Num)
b = np.random.randn(1)
y = b*x + np.random.randn(Num)*0.5
xx = np.linspace(min(x), max(x), Num)
plt.plot(x,marker='.')#,ls='')
print(b)
#plt.plot(y)
plt.plot(xx)
# Out:
# [-1.6644422]

# %%
b1 = ((x.T) * x)
b2 = np.linalg.inv(b1)
#b1 = b1 * b.T * y
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-40-56c36a088c51> in <module>()
#       1 b1 = ((x.T) * x)
# ----> 2 b2 = np.linalg.inv(b1)
#       3 #b1 = b1 * b.T * y
#
# ~/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/numpy/linalg/linalg.py in inv(a)
#     524     """
#     525     a, wrap = _makearray(a)
# --> 526     _assertRankAtLeast2(a)
#     527     _assertNdSquareness(a)
#     528     t, result_t = _commonType(a)
#
# ~/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/numpy/linalg/linalg.py in _assertRankAtLeast2(*arrays)
#     202         if a.ndim < 2:
#     203             raise LinAlgError('%d-dimensional array given. Array must be '
# --> 204                     'at least two-dimensional' % a.ndim)
#     205
#     206 def _assertSquareness(*arrays):
#
# LinAlgError: 1-dimensional array given. Array must be at least two-dimensional
